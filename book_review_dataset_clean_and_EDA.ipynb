# %% [markdown]
# The data is found on Kaggle [Amazon Books Reviews](https://www.kaggle.com/datasets/mohamedbakhet/amazon-books-reviews).

# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## Book

# %%
# read the book data
books = pd.read_csv('books_data.csv')

# %%
# top 5
books.head()
# Out:
#                                                Title  \
# 0                     Its Only Art If Its Well Hung!
# 1                           Dr. Seuss: American Icon
# 2              Wonderful Worship in Smaller Churches
# 3                      Whispers of the Wicked Saints
# 4  Nation Dance: Religion, Identity and Cultural ...
#
#                                          description              authors  \
# 0                                                NaN     ['Julie Strain']
# 1  Philip Nel takes a fascinating look into the k...       ['Philip Nel']
# 2  This resource includes twelve principles in un...     ['David R. Ray']
# 3  Julia Thomas finds her life spinning out of co...  ['Veronica Haddon']
# 4                                                NaN      ['Edward Long']
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
# 3  http://books.google.com/books/content?id=aRSIg...
# 4                                                NaN
#
#                                          previewLink  publisher publishedDate  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN          1996
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN          2000
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...  iUniverse       2005-02
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...        NaN    2003-03-01
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...
#
#                       categories  ratingsCount
# 0    ['Comics & Graphic Novels']           NaN
# 1  ['Biography & Autobiography']           NaN
# 2                   ['Religion']           NaN
# 3                    ['Fiction']           NaN
# 4                            NaN           NaN

# %%
# dimension
books.shape
# Out:
# (212404, 10)

# %%
# data types
books.dtypes
# Out:
# Title             object
# description       object
# authors           object
# image             object
# previewLink       object
# publisher         object
# publishedDate     object
# infoLink          object
# categories        object
# ratingsCount     float64
# dtype: object

# %%
# check the NaN values for each column and order them in descending order
books.isnull().sum().sort_values(ascending=False)
# Out:
# ratingsCount     162652
# publisher         75886
# description       68442
# image             52075
# categories        41199
# authors           31413
# publishedDate     25305
# previewLink       23836
# infoLink          23836
# Title                 1
# dtype: int64

# %%
# count the NaN values for each column and calculate the percentage of NaN values and order them in descending order
nan_values = books.isnull().sum().sort_values(ascending=False)
nan_values = nan_values[nan_values > 0]
nan_values_percentage = nan_values / len(books) * 100
nan_values_percentage
# Out:
# ratingsCount     76.576712
# publisher        35.727199
# description      32.222557
# image            24.516958
# categories       19.396527
# authors          14.789270
# publishedDate    11.913617
# previewLink      11.222011
# infoLink         11.222011
# Title             0.000471
# dtype: float64

# %% [markdown]
# null values in "ratingsCount" is more than 76%. Thus, it's not very useful.

# %%
# 162652 / 212404

# %% [markdown]
# ### Sample 10%

# %%
# sample 10% of the data
books_sample = books.sample(frac=0.1)

# %%
# sample 10 rows
books_sample.sample(10)
# Out:
#                                                     Title  \
# 44456   Cracking the SAT II: Math, 1999-2000 Edition (...
# 161166  The Devils of His Own Creation: The Life and W...
# 131769                   The long road of woman's memory,
# 145831            Burmese Days: A Novel (Library Edition)
# 190943                                   Rent: Easy Piano
# 163730                       Who Will Speak for the Lamb?
# 190373  The Trading Athlete: Winning the Mental Game o...
# 125608  Restaurant Secrets of Orange County & Other Gr...
# 117270   Study Without Stress: Mastering Medical Sciences
# 148296                             Daughter of the Shaman
#
#                                               description  \
# 44456   WE KNOW THE SAT II: ENGLISH The experts at The...
# 161166  Richard Matheson, author of "I Am Legend," has...
# 131769  For many years at Hull-House I have at interva...
# 145831  First published in 1934, George Orwell's first...
# 190943  (Easy Piano Vocal Selections). 12 songs from t...
# 163730  Although at first antagonistic to one another,...
# 190373  "The best traders in the world know that being...
# 125608                                                NaN
# 117270  Too much to learn, too little time! Nothing ch...
# 148296                                                NaN
#
#                                                   authors  \
# 44456                      ['Liz Buffa', 'Adam Robinson']
# 161166  ['Stanley Wiater', 'Matthew Bradley', 'Paul St...
# 131769                                    ['Jane Addams']
# 145831                                  ['George Orwell']
# 190943                                ['Jonathan Larson']
# 163730                                   ['Mildred Ames']
# 190373                ['Shane Murphy', 'Doug Hirschhorn']
# 125608                ['Entertainment Publications, Inc']
# 117270       ['Eugenia G. Kelman', 'Kathleen C. Straker']
# 148296                                                NaN
#
#                                                     image  \
# 44456   http://books.google.com/books/content?id=8wu1F...
# 161166  http://books.google.com/books/content?id=YLsun...
# 131769  http://books.google.com/books/content?id=CQi9D...
# 145831  http://books.google.com/books/content?id=xuQ6z...
# 190943  http://books.google.com/books/content?id=nqMLA...
# 163730  http://books.google.com/books/content?id=Y2O6i...
# 190373  http://books.google.com/books/content?id=zvCSA...
# 125608                                                NaN
# 117270  http://books.google.com/books/content?id=Gj2He...
# 148296                                                NaN
#
#                                               previewLink  \
# 44456   http://books.google.com/books?id=8wu1FyXgUOUC&...
# 161166  http://books.google.com/books?id=YLsunUB90q4C&...
# 131769  http://books.google.nl/books?id=CQi9DwAAQBAJ&p...
# 145831  http://books.google.com/books?id=xuQ6zwEACAAJ&...
# 190943  http://books.google.com/books?id=nqMLAAAACAAJ&...
# 163730  http://books.google.com/books?id=Y2O6i6pCbQEC&...
# 190373  http://books.google.com/books?id=zvCSAQAACAAJ&...
# 125608  http://books.google.nl/books?id=WEeaYgEACAAJ&d...
# 117270  http://books.google.nl/books?id=Gj2HeccWyXoC&p...
# 148296                                                NaN
#
#                             publisher publishedDate  \
# 44456                Princeton Review    1999-03-02
# 161166                  Citadel Press          2009
# 131769              Prabhat Prakashan    2021-01-01
# 145831                            NaN    2021-06-10
# 190943        Hal Leonard Corporation    1997-06-01
# 163730  Harpercollins Childrens Books          1989
# 190373                          Wiley    2001-08-30
# 125608                            NaN          1998
# 117270                           SAGE    1999-10-22
# 148296                            NaN           NaN
#
#                                                  infoLink  \
# 44456   http://books.google.com/books?id=8wu1FyXgUOUC&...
# 161166  http://books.google.com/books?id=YLsunUB90q4C&...
# 131769  https://play.google.com/store/books/details?id...
# 145831  http://books.google.com/books?id=xuQ6zwEACAAJ&...
# 190943  http://books.google.com/books?id=nqMLAAAACAAJ&...
# 163730  http://books.google.com/books?id=Y2O6i6pCbQEC&...
# 190373  http://books.google.com/books?id=zvCSAQAACAAJ&...
# 125608  http://books.google.nl/books?id=WEeaYgEACAAJ&d...
# 117270  http://books.google.nl/books?id=Gj2HeccWyXoC&d...
# 148296                                                NaN
#
#                                     categories  ratingsCount
# 44456   ['College entrance achievement tests']           NaN
# 161166           ['Biography & Autobiography']           NaN
# 131769                             ['Fiction']           NaN
# 145831                             ['Fiction']          37.0
# 190943                               ['Music']           NaN
# 163730                      ['Animal welfare']           NaN
# 190373                ['Business & Economics']           NaN
# 125608                             ['Cooking']           NaN
# 117270                           ['Education']           1.0
# 148296                                     NaN           NaN

# %% [markdown]
# * There are NaN values in some columns like description, image, publisher, categories, ratingCount.
# * The authors and categories contain middle bracket which needs additional data cleanse (remove []).
# * The publishedDate is quite messy. Some have year, year and month, and year and month and date.

# %%
# data type
books_sample.dtypes
# Out:
# Title             object
# description       object
# authors           object
# image             object
# previewLink       object
# publisher         object
# publishedDate     object
# infoLink          object
# categories        object
# ratingsCount     float64
# dtype: object

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### authors

# %%
# remove middle brackets from the 'authors' column
books_sample['authors'] = books_sample['authors'].str.replace('[', '')
books_sample['authors'] = books_sample['authors'].str.replace(']', '')

# %%
# top 5
books_sample.head()
# Out:
#                                                     Title  \
# 88524   A Serpent in Eden (A Harlequin Romance, No. 1662)
# 73183   The Long March: The Choctaw's Gift to Irish Fa...
# 5557    Presence and Desire: Essays on Gender, Sexuali...
# 143939                  Stirling Moss: My Cars, My Career
# 80114   Criminal Kabbalah: An Intriguing Anthology of ...
#
#                                               description  \
# 88524                                                 NaN
# 73183   In 1847, an impoverished group of Choctaw Indi...
# 5557    Explores current controversies and significant...
# 143939  Until Stirling Moss's front-line career was cu...
# 80114                                                 NaN
#
#                             authors  \
# 88524                           NaN
# 73183    'Marie-Louise Fitzpatrick'
# 5557                   'Jill Dolan'
# 143939  'Stirling Moss', 'Doug Nye'
# 80114                           NaN
#
#                                                     image  \
# 88524                                                 NaN
# 73183   http://books.google.com/books/content?id=L81oP...
# 5557    http://books.google.com/books/content?id=jdi03...
# 143939                                                NaN
# 80114                                                 NaN
#
#                                               previewLink  \
# 88524                                                 NaN
# 73183   http://books.google.com/books?id=L81oPwAACAAJ&...
# 5557    http://books.google.nl/books?id=jdi03k6YYPAC&p...
# 143939  http://books.google.com/books?id=Z8USPAAACAAJ&...
# 80114                                                 NaN
#
#                            publisher publishedDate  \
# 88524                            NaN           NaN
# 73183        Beyond Words Publishing          1998
# 5557    University of Michigan Press          1993
# 143939                           NaN          1987
# 80114                            NaN           NaN
#
#                                                  infoLink  \
# 88524                                                 NaN
# 73183   http://books.google.com/books?id=L81oPwAACAAJ&...
# 5557    http://books.google.nl/books?id=jdi03k6YYPAC&d...
# 143939  http://books.google.com/books?id=Z8USPAAACAAJ&...
# 80114                                                 NaN
#
#                            categories  ratingsCount
# 88524                             NaN           NaN
# 73183             ['Choctaw Indians']           1.0
# 5557               ['Social Science']           NaN
# 143939  ['Automobile racing drivers']           NaN
# 80114                             NaN           NaN

# %%
# remove the leading and trailing single quotes from the 'authors' column
books_sample['authors'] = books_sample['authors'].str.strip("'")

# %%
# top 5 
books_sample.head()
# Out:
#                                                     Title  \
# 88524   A Serpent in Eden (A Harlequin Romance, No. 1662)
# 73183   The Long March: The Choctaw's Gift to Irish Fa...
# 5557    Presence and Desire: Essays on Gender, Sexuali...
# 143939                  Stirling Moss: My Cars, My Career
# 80114   Criminal Kabbalah: An Intriguing Anthology of ...
#
#                                               description  \
# 88524                                                 NaN
# 73183   In 1847, an impoverished group of Choctaw Indi...
# 5557    Explores current controversies and significant...
# 143939  Until Stirling Moss's front-line career was cu...
# 80114                                                 NaN
#
#                           authors  \
# 88524                         NaN
# 73183    Marie-Louise Fitzpatrick
# 5557                   Jill Dolan
# 143939  Stirling Moss', 'Doug Nye
# 80114                         NaN
#
#                                                     image  \
# 88524                                                 NaN
# 73183   http://books.google.com/books/content?id=L81oP...
# 5557    http://books.google.com/books/content?id=jdi03...
# 143939                                                NaN
# 80114                                                 NaN
#
#                                               previewLink  \
# 88524                                                 NaN
# 73183   http://books.google.com/books?id=L81oPwAACAAJ&...
# 5557    http://books.google.nl/books?id=jdi03k6YYPAC&p...
# 143939  http://books.google.com/books?id=Z8USPAAACAAJ&...
# 80114                                                 NaN
#
#                            publisher publishedDate  \
# 88524                            NaN           NaN
# 73183        Beyond Words Publishing          1998
# 5557    University of Michigan Press          1993
# 143939                           NaN          1987
# 80114                            NaN           NaN
#
#                                                  infoLink  \
# 88524                                                 NaN
# 73183   http://books.google.com/books?id=L81oPwAACAAJ&...
# 5557    http://books.google.nl/books?id=jdi03k6YYPAC&d...
# 143939  http://books.google.com/books?id=Z8USPAAACAAJ&...
# 80114                                                 NaN
#
#                            categories  ratingsCount
# 88524                             NaN           NaN
# 73183             ['Choctaw Indians']           1.0
# 5557               ['Social Science']           NaN
# 143939  ['Automobile racing drivers']           NaN
# 80114                             NaN           NaN

# %%
# count unique values in the 'authors' column
books_sample['authors'].nunique()
# Out:
# 16463

# %% [markdown]
# There are 16529 distinct author(s).

# %%
# group by 'authors' and count the number of books for each author and sort them in descending order
authors_books = books_sample.groupby('authors').size().sort_values(ascending=False)

# %%
# top 10
authors_books.head(20)
# Out:
# authors
# William Shakespeare                      24
# Library of Congress. Copyright Office    21
# "Louis L'Amour"                          18
# Rose Arny                                18
# Agatha Christie                          18
# Erle Stanley Gardner                     17
# Edgar Rice Burroughs                     14
# Robert Louis Stevenson                   10
# Charles Dickens                          10
# Rudyard Kipling                           9
# Mark Twain                                9
# Various                                   8
# Nora Roberts                              8
# Virginia Woolf                            8
# Henry James                               8
# Arthur James Wells                        7
# Ray Bradbury                              7
# Joseph Conrad                             7
# Anthony Trollope                          7
# Ernest Hemingway                          7
# dtype: int64

# %% [markdown]
# The "authors" column needs additional data cleaning. For example, remove the leading and trailing double quotes. And some authors are hard to relate to a specific person like "Library of Congress" and "DK".

# %%
# remove the leading and trailing double quotes from the 'authors' column
books_sample['authors'] = books_sample['authors'].str.strip('"')

# %%
# group by 'authors' and count the number of books for each author and sort them in descending order
books_sample.groupby('authors').size().sort_values(ascending=False).head(20)
# Out:
# authors
# William Shakespeare                      24
# Library of Congress. Copyright Office    21
# Agatha Christie                          18
# Louis L'Amour                            18
# Rose Arny                                18
# Erle Stanley Gardner                     17
# Edgar Rice Burroughs                     14
# Charles Dickens                          10
# Robert Louis Stevenson                   10
# Mark Twain                                9
# Rudyard Kipling                           9
# Henry James                               8
# Virginia Woolf                            8
# Various                                   8
# Nora Roberts                              8
# Ann M. Martin                             7
# Ernest Hemingway                          7
# Leslie Charteris                          7
# Arthur Conan Doyle                        7
# Anthony Trollope                          7
# dtype: int64

# %% [markdown]
# #### Replace the whole dataset

# %% [markdown]
# #### categories

# %%
# remove the middle brackets from the 'categories' column
books_sample['categories'] = books_sample['categories'].str.replace('[', '')
books_sample['categories'] = books_sample['categories'].str.replace(']', '')

# remove the leading and trailing single quotes from the 'categories' column
books_sample['categories'] = books_sample['categories'].str.strip("'")

# %%
# top 5
books_sample.head()
# Out:
#                                                     Title  \
# 88524   A Serpent in Eden (A Harlequin Romance, No. 1662)
# 73183   The Long March: The Choctaw's Gift to Irish Fa...
# 5557    Presence and Desire: Essays on Gender, Sexuali...
# 143939                  Stirling Moss: My Cars, My Career
# 80114   Criminal Kabbalah: An Intriguing Anthology of ...
#
#                                               description  \
# 88524                                                 NaN
# 73183   In 1847, an impoverished group of Choctaw Indi...
# 5557    Explores current controversies and significant...
# 143939  Until Stirling Moss's front-line career was cu...
# 80114                                                 NaN
#
#                           authors  \
# 88524                         NaN
# 73183    Marie-Louise Fitzpatrick
# 5557                   Jill Dolan
# 143939  Stirling Moss', 'Doug Nye
# 80114                         NaN
#
#                                                     image  \
# 88524                                                 NaN
# 73183   http://books.google.com/books/content?id=L81oP...
# 5557    http://books.google.com/books/content?id=jdi03...
# 143939                                                NaN
# 80114                                                 NaN
#
#                                               previewLink  \
# 88524                                                 NaN
# 73183   http://books.google.com/books?id=L81oPwAACAAJ&...
# 5557    http://books.google.nl/books?id=jdi03k6YYPAC&p...
# 143939  http://books.google.com/books?id=Z8USPAAACAAJ&...
# 80114                                                 NaN
#
#                            publisher publishedDate  \
# 88524                            NaN           NaN
# 73183        Beyond Words Publishing          1998
# 5557    University of Michigan Press          1993
# 143939                           NaN          1987
# 80114                            NaN           NaN
#
#                                                  infoLink  \
# 88524                                                 NaN
# 73183   http://books.google.com/books?id=L81oPwAACAAJ&...
# 5557    http://books.google.nl/books?id=jdi03k6YYPAC&d...
# 143939  http://books.google.com/books?id=Z8USPAAACAAJ&...
# 80114                                                 NaN
#
#                        categories  ratingsCount
# 88524                         NaN           NaN
# 73183             Choctaw Indians           1.0
# 5557               Social Science           NaN
# 143939  Automobile racing drivers           NaN
# 80114                         NaN           NaN

# %%
# count unique values in the 'categories' column
books_sample['categories'].nunique()
# Out:
# 2380

# %%
# group by 'categories' and count the number of books for each category and sort them in descending order
categories_books = books_sample.groupby('categories').size().sort_values(ascending=False)

# %%
# top 20
categories_books.head(20)
# Out:
# categories
# Fiction                        2271
# Religion                        930
# History                         913
# Juvenile Fiction                704
# Biography & Autobiography       651
# Business & Economics            567
# Computers                       474
# Social Science                  387
# Juvenile Nonfiction             320
# Education                       305
# Science                         268
# Cooking                         249
# Family & Relationships          233
# Sports & Recreation             229
# Music                           225
# Psychology                      207
# Health & Fitness                201
# Political Science               199
# Literary Criticism              197
# Language Arts & Disciplines     195
# dtype: int64

# %% [markdown]
# Most of them are fiction books.

# %%
# calculate the percentage of books for each category
categories_books_percentage = categories_books / len(books_sample) * 100

# %%
    # top 20
categories_books_percentage.head(20)
# Out:
# categories
# Fiction                        10.692090
# Religion                        4.378531
# History                         4.298493
# Juvenile Fiction                3.314501
# Biography & Autobiography       3.064972
# Business & Economics            2.669492
# Computers                       2.231638
# Social Science                  1.822034
# Juvenile Nonfiction             1.506591
# Education                       1.435970
# Science                         1.261770
# Cooking                         1.172316
# Family & Relationships          1.096987
# Sports & Recreation             1.078154
# Music                           1.059322
# Psychology                      0.974576
# Health & Fitness                0.946328
# Political Science               0.936911
# Literary Criticism              0.927495
# Language Arts & Disciplines     0.918079
# dtype: float64

# %% [markdown]
# Fiction books account for over 11%.

# %% [markdown]
# #### publishedDate

# %%
# extract the year from the 'published_date' column using the 'str.extract' method and regular expression pattern
books_sample['year'] = books_sample['publishedDate'].str.extract(r'(\d{4})')

# %%
# top 5
books_sample.head()
# Out:
#                                                     Title  \
# 88524   A Serpent in Eden (A Harlequin Romance, No. 1662)
# 73183   The Long March: The Choctaw's Gift to Irish Fa...
# 5557    Presence and Desire: Essays on Gender, Sexuali...
# 143939                  Stirling Moss: My Cars, My Career
# 80114   Criminal Kabbalah: An Intriguing Anthology of ...
#
#                                               description  \
# 88524                                                 NaN
# 73183   In 1847, an impoverished group of Choctaw Indi...
# 5557    Explores current controversies and significant...
# 143939  Until Stirling Moss's front-line career was cu...
# 80114                                                 NaN
#
#                           authors  \
# 88524                         NaN
# 73183    Marie-Louise Fitzpatrick
# 5557                   Jill Dolan
# 143939  Stirling Moss', 'Doug Nye
# 80114                         NaN
#
#                                                     image  \
# 88524                                                 NaN
# 73183   http://books.google.com/books/content?id=L81oP...
# 5557    http://books.google.com/books/content?id=jdi03...
# 143939                                                NaN
# 80114                                                 NaN
#
#                                               previewLink  \
# 88524                                                 NaN
# 73183   http://books.google.com/books?id=L81oPwAACAAJ&...
# 5557    http://books.google.nl/books?id=jdi03k6YYPAC&p...
# 143939  http://books.google.com/books?id=Z8USPAAACAAJ&...
# 80114                                                 NaN
#
#                            publisher publishedDate  \
# 88524                            NaN           NaN
# 73183        Beyond Words Publishing          1998
# 5557    University of Michigan Press          1993
# 143939                           NaN          1987
# 80114                            NaN           NaN
#
#                                                  infoLink  \
# 88524                                                 NaN
# 73183   http://books.google.com/books?id=L81oPwAACAAJ&...
# 5557    http://books.google.nl/books?id=jdi03k6YYPAC&d...
# 143939  http://books.google.com/books?id=Z8USPAAACAAJ&...
# 80114                                                 NaN
#
#                        categories  ratingsCount  year
# 88524                         NaN           NaN   NaN
# 73183             Choctaw Indians           1.0  1998
# 5557               Social Science           NaN  1993
# 143939  Automobile racing drivers           NaN  1987
# 80114                         NaN           NaN   NaN

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Number of books by authors

# %%
# draw a bar plot for the top 20 authors using plotly excluding "Library of Congress. Copyright Office" and "DK"
import plotly.express as px

# group by 'authors' and count the number of books for each author and sort them in descending order
authors_books = books_sample.groupby('authors').size().sort_values(ascending=False)

# remove "Library of Congress. Copyright Office" and "DK"
authors_books = authors_books.drop(["Library of Congress. Copyright Office", "DK"])

fig = px.bar(authors_books.head(20), x=authors_books.head(20).index, y=authors_books.head(20).values, title='Top 20 Authors', labels={'x': 'Authors', 'y': 'Number of Books'})
fig.show()

# %% [markdown]
# #### Number of books by Category

# %%
# draw a bar plot for the top 20 categories using plotly
# group by 'categories' and count the number of books for each category and sort them in descending order
categories_books = books_sample.groupby('categories').size().sort_values(ascending=False)

fig = px.bar(categories_books.head(20), x=categories_books.head(20).index, y=categories_books.head(20).values, title='Top 20 Categories', labels={'x': 'Categories', 'y': 'Number of Books'})
fig.show()

# %% [markdown]
# #### number of books by published year

# %%
# draw a line plot for the number of books published each year using plotly
# group by 'year' and count the number of books for each year and sort them in ascending order
books_per_year = books_sample.groupby('year').size().sort_index()

fig = px.line(books_per_year, title='Number of Books Published Each Year', labels={'x': 'Year', 'y': 'Number of Books'})
fig.show()

# %% [markdown]
# ## Ratings

# %%
# read the ratings data
ratings = pd.read_csv('Books_rating.csv')

# %%
# top 5
ratings.head()
# Out:
#            Id                           Title  Price         User_id  \
# 0  1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1  0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2  0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3  0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# 4  0826414346        Dr. Seuss: American Icon    NaN  A22X4XUPKF66MR
#
#                           profileName review/helpfulness  review/score  \
# 0               Jim of Oz "jim-of-oz"                7/7           4.0
# 1                       Kevin Killian              10/10           5.0
# 2                        John Granger              10/11           5.0
# 3  Roy E. Perry "amateur philosopher"                7/7           4.0
# 4     D. H. Richards "ninthwavestore"                3/3           4.0
#
#    review/time                                   review/summary  \
# 0    940636800           Nice collection of Julie Strain images
# 1   1095724800                                Really Enjoyed It
# 2   1078790400  Essential for every personal and Public Library
# 3   1090713600  Phlip Nel gives silly Seuss a serious treatment
# 4   1107993600                           Good academic overview
#
#                                          review/text
# 0  This is only for Julie Strain fans. It's a col...
# 1  I don't care much for Dr. Seuss but after read...
# 2  If people become the books they read and if "t...
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...
# 4  Philip Nel - Dr. Seuss: American IconThis is b...

# %%
# shape
ratings.shape
# Out:
# (3000000, 10)

# %%
# data types
ratings.dtypes
# Out:
# Id                     object
# Title                  object
# Price                 float64
# User_id                object
# profileName            object
# review/helpfulness     object
# review/score          float64
# review/time             int64
# review/summary         object
# review/text            object
# dtype: object

# %%
# null values and order them in descending order
ratings.isnull().sum().sort_values(ascending=False)
# Out:
# Price                 2518829
# profileName            561905
# User_id                561787
# review/summary            407
# Title                     208
# review/text                 8
# Id                          0
# review/helpfulness          0
# review/score                0
# review/time                 0
# dtype: int64

# %% [markdown]
# "review helpfulness" and "review score" have very good quality. They can be used to train models.

# %%
# count the NaN values for each column and calculate the percentage of NaN values and order them in descending order
nan_values = ratings.isnull().sum().sort_values(ascending=False)
nan_values = nan_values[nan_values > 0]
nan_values_percentage = nan_values / len(ratings) * 100
nan_values_percentage
# Out:
# Price             83.960967
# profileName       18.730167
# User_id           18.726233
# review/summary     0.013567
# Title              0.006933
# review/text        0.000267
# dtype: float64

# %% [markdown]
# null values in "Price" is over 83%. Thus, it's not very useful.

# %% [markdown]
# ### Sample 10%

# %%
# sample 10% of the data
ratings_sample = ratings.sample(frac=0.1)

# %%
# top 5
ratings_sample.head()
# Out:
#                  Id                                              Title  Price  \
# 589191   B0007DVI6U          Imperial Spain, 1469-1716 (A Mentor book)    NaN
# 2839038  B0007UUXS2  The Turning.(Book Review): An article from: Re...   5.95
# 675953   B000Q6XPDW                               The Poisonwood Bible    NaN
# 908977   0786118490                                         Persuasion    NaN
# 1859941  0963083732                                          The Bride  10.00
#
#                 User_id                                      profileName  \
# 589191   A1VTLVBEA1CW87                        Stella Mather "BookRaves"
# 2839038  A1TX8R0XZAFM1Y                       Paul R. Sheringham "Shero"
# 675953   A2S166WSCFIFP5  adead_poet@hotmail.com "adead_poet@hotmail.com"
# 908977   A1IRT0ZGQ7QGJ5                                               LR
# 1859941   AA28RTZQSGP5Y                                               MW
#
#         review/helpfulness  review/score  review/time  \
# 589191                 0/1           4.0   1297555200
# 2839038                5/7           5.0   1128729600
# 675953                 2/3           5.0   1218326400
# 908977                 5/6           5.0   1187222400
# 1859941                0/0           5.0   1231200000
#
#                                           review/summary  \
# 589191         excellent history of culture and politics
# 2839038                                      The turning
# 675953   I can't say enough good things about this novel
# 908977                                     Persuasion...
# 1859941                      Sound teacher of the Bible!
#
#                                                review/text
# 589191   I bought this after seeing the Met HD broadcas...
# 2839038  The characters in these stories are so vivid. ...
# 675953   I love the Poisonwood Bible. It's easily on my...
# 908977   is Austen's novel which begins with Anne Ellio...
# 1859941  Any thing by Brian Bailey is solid, sound and ...

# %% [markdown]
# * There are NULL values in some columns.
# * Need to convert "review/time" to a datetime format.

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### review/time

# %%
# convert "review/time" from integer to datetime
ratings_sample['review/time'] = pd.to_datetime(ratings_sample['review/time'], unit='s')

# %%
# top 5
ratings_sample.head()
# Out:
#                  Id                                              Title  Price  \
# 589191   B0007DVI6U          Imperial Spain, 1469-1716 (A Mentor book)    NaN
# 2839038  B0007UUXS2  The Turning.(Book Review): An article from: Re...   5.95
# 675953   B000Q6XPDW                               The Poisonwood Bible    NaN
# 908977   0786118490                                         Persuasion    NaN
# 1859941  0963083732                                          The Bride  10.00
#
#                 User_id                                      profileName  \
# 589191   A1VTLVBEA1CW87                        Stella Mather "BookRaves"
# 2839038  A1TX8R0XZAFM1Y                       Paul R. Sheringham "Shero"
# 675953   A2S166WSCFIFP5  adead_poet@hotmail.com "adead_poet@hotmail.com"
# 908977   A1IRT0ZGQ7QGJ5                                               LR
# 1859941   AA28RTZQSGP5Y                                               MW
#
#         review/helpfulness  review/score review/time  \
# 589191                 0/1           4.0  2011-02-13
# 2839038                5/7           5.0  2005-10-08
# 675953                 2/3           5.0  2008-08-10
# 908977                 5/6           5.0  2007-08-16
# 1859941                0/0           5.0  2009-01-06
#
#                                           review/summary  \
# 589191         excellent history of culture and politics
# 2839038                                      The turning
# 675953   I can't say enough good things about this novel
# 908977                                     Persuasion...
# 1859941                      Sound teacher of the Bible!
#
#                                                review/text
# 589191   I bought this after seeing the Met HD broadcas...
# 2839038  The characters in these stories are so vivid. ...
# 675953   I love the Poisonwood Bible. It's easily on my...
# 908977   is Austen's novel which begins with Anne Ellio...
# 1859941  Any thing by Brian Bailey is solid, sound and ...

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Number of reviews by book

# %%
# number of reviews by book title
title_ratings =  ratings_sample.groupby('Title').size().sort_values(ascending=False)

# %%
# top 20
title_ratings.head(20)
# Out:
# Title
# The Hobbit                                                          2193
# Pride and Prejudice                                                 1949
# Atlas Shrugged                                                      1259
# Wuthering Heights                                                   1140
# The Giver                                                            783
# Great Expectations                                                   744
# Of Mice and Men                                                      709
# Harry Potter and The Sorcerer's Stone                                676
# Brave New World                                                      642
# Mere Christianity                                                    626
# Persuasion                                                           590
# The Picture of Dorian Gray                                           587
# To kill a mockingbird                                                496
# The Great Gatsby                                                     495
# The Scarlet Letter A Romance                                         459
# The Hobbit or There and Back Again                                   457
# The Hobbit; Or, There and Back Again                                 447
# Fahrenheit 451                                                       447
# The Hobbitt, or there and back again; illustrated by the author.     443
# The Hobbit There and Back Again                                      428
# dtype: int64

# %%
# draw a bar plot for the top 20 books with the most reviews using plotly
fig = px.bar(title_ratings.head(20), x=title_ratings.head(20).index, y=title_ratings.head(20).values, title='Top 20 Books with the Most Reviews', labels={'x': 'Books', 'y': 'Number of Reviews'})
fig.show()

# %% [markdown]
# #### review helpfulness

# %%
# number of reviews by review helpfulness
helpfulness_ratings =  ratings_sample.groupby('review/helpfulness').size().sort_values(ascending=False)

# top 20
helpfulness_ratings.head(20)
# Out:
# review/helpfulness
# 0/0    88813
# 1/1    31279
# 2/2    15593
# 0/1    12886
# 1/2     9961
# 3/3     9346
# 2/3     6612
# 4/4     6213
# 3/4     4795
# 5/5     4275
# 0/2     4176
# 1/3     3817
# 4/5     3600
# 6/6     3062
# 2/4     2990
# 5/6     2496
# 7/7     2381
# 3/5     2175
# 6/7     1976
# 0/3     1846
# dtype: int64

# %%
# draw a bar plot for the top 20 review helpfulness using plotly
fig = px.bar(helpfulness_ratings.head(20), x=helpfulness_ratings.head(20).index, y=helpfulness_ratings.head(20).values, title='Top 20 Review Helpfulness', labels={'x': 'Review Helpfulness', 'y': 'Number of Reviews'})
fig.show()

# %% [markdown]
# #### Review text

# %%
# !pip install wordcloud

# %%
# data type
# ratings_sample.dtypes

# %%
# draw a cloud word for the book review text
# convert any non-string values to strings and then join
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# convert any non-string values to strings and then join
text = ' '.join([str(review) for review in ratings_sample['review/text']])
wordcloud = WordCloud(width=800, height=400).generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# draw a cloud word for book review text excluding the stop words
from wordcloud import STOPWORDS

# convert any non-string values to strings and then join
text = ' '.join([str(review) for review in ratings_sample['review/text']])
wordcloud = WordCloud(width=800, height=400, stopwords=STOPWORDS).generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# word frequency for the book review text excluding the stop words
from collections import Counter

# convert any non-string values to strings and then join
text = ' '.join([str(review) for review in ratings_sample['review/text']])
word_list = text.split()
word_freq = Counter(word_list)

# exclude the stop words
for word in list(word_freq):
    if word in STOPWORDS:
        del word_freq[word]

# %%
# top 20
word_freq.most_common(20)
# Out:
# [('I', 680809),
#  ('book', 405695),
#  ('The', 228623),
#  ('read', 170794),
#  ('one', 143373),
#  ('This', 133036),
#  ('It', 108658),
#  ('will', 99906),
#  ('story', 87626),
#  ('good', 71263),
#  ('many', 69821),
#  ('book.', 67154),
#  ('great', 66659),
#  ('first', 65212),
#  ('reading', 64554),
#  ('much', 63278),
#  ('really', 60767),
#  ('books', 60046),
#  ('time', 59366),
#  ('-', 57437)]

# %% [markdown]
# ## Join Two

# %%
# join the book data with the ratings data on the 'ISBN' column
books_ratings = pd.merge(books, ratings, on='Title')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42032\2864659481.py in ?()
#       1 # join the book data with the ratings data on the 'ISBN' column
# ----> 2 books_ratings = pd.merge(books, ratings, on='Title')
#
# c:\Users\jcheng\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# c:\Users\jcheng\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\jcheng\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1306                     if lk is not None:
#    1307                         # Then we're either Hashable or a wrong-length arraylike,
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#    1313                         # work-around for merge_asof(left_index=True)
#
# c:\Users\jcheng\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'Title'

# %%
# top 5
# books_ratings.head()

# %%
# data types
books_ratings.dtypes
# Out:
# Title                  object
# description            object
# authors                object
# image                  object
# previewLink            object
# publisher              object
# publishedDate          object
# infoLink               object
# categories             object
# ratingsCount          float64
# Id                     object
# Price                 float64
# User_id                object
# profileName            object
# review/helpfulness     object
# review/score          float64
# review/time             int64
# review/summary         object
# review/text            object
# dtype: object

# %%
# data shape
books_ratings.shape
# Out:
# (3000000, 19)

# %% [markdown]
# ## Final

# %%
# check the NaN values for each column and order them in descending order
books_ratings.isnull().sum().sort_values(ascending=False)
# Out:
# Price                 2518829
# ratingsCount          1360694
# publisher              782617
# description            640225
# profileName            561905
# User_id                561787
# categories             551498
# image                  540306
# authors                390634
# publishedDate          354581
# previewLink            330623
# infoLink               330623
# review/summary            407
# Title                     208
# review/text                 8
# review/helpfulness          0
# review/score                0
# review/time                 0
# Id                          0
# dtype: int64

# %%
# calculate the percentage of NaN values for each column and order them in descending order
nan_values = books_ratings.isnull().sum().sort_values(ascending=False)
nan_values = nan_values[nan_values > 0]
nan_values_percentage = nan_values / len(books_ratings) * 100
nan_values_percentage
# Out:
# Price             83.960967
# ratingsCount      45.356467
# publisher         26.087233
# description       21.340833
# profileName       18.730167
# User_id           18.726233
# categories        18.383267
# image             18.010200
# authors           13.021133
# publishedDate     11.819367
# previewLink       11.020767
# infoLink          11.020767
# review/summary     0.013567
# Title              0.006933
# review/text        0.000267
# dtype: float64

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Author

# %%
## authors ##
# remove middle brackets from the 'authors' column
books_ratings['authors'] = books_ratings['authors'].str.replace('[', '')
books_ratings['authors'] = books_ratings['authors'].str.replace(']', '')
# remove the leading and trailing single quotes from the 'authors' column
# books_ratings['authors'] = books_ratings['authors'].str.strip("'")
# remove the single quotes from the 'authors' column
books_ratings['authors'] = books_ratings['authors'].str.replace("'", '')
# remove the leading and trailing double quotes from the 'authors' column
books_ratings['authors'] = books_ratings['authors'].str.strip('"')

# %%
# sample 50 for the authors excluding the NaN values and duplicates
# books_ratings['authors'].dropna().drop_duplicates().sample(50)

# %% [markdown]
# #### published_year

# %%
## publish year ##
# extract the year from the 'published_date' column using the 'str.extract' method and regular expression pattern
books_ratings['published_year'] = books_ratings['publishedDate'].str.extract(r'(\d{4})')

# %%
# top 5
# books_ratings.head()

# %%
## categories ##
# remove the middle brackets from the 'categories' column
books_ratings['categories'] = books_ratings['categories'].str.replace('[', '')
books_ratings['categories'] = books_ratings['categories'].str.replace(']', '')
# remove the leading and trailing single quotes from the 'categories' column
books_ratings['categories'] = books_ratings['categories'].str.strip("'")
# remove the single quotes from the 'categories' column
books_ratings['categories'] = books_ratings['categories'].str.replace("'", '')

# %%
# sample 50 for the categories excluding the NaN values and duplicates
# books_ratings['categories'].dropna().drop_duplicates().sample(50)

# %% [markdown]
# #### review/time

# %%
## review time ##
# convert "review/time" from integer to datetime
books_ratings['review/time'] = pd.to_datetime(books_ratings['review/time'], unit='s')

# %%
# top 5
# books_ratings.head()

# %% [markdown]
# #### review_id

# %%
# create a unique identifier for each row
books_ratings['review_id'] = books_ratings.index + 1

# %% [markdown]
# #### helpfulness_ratio

# %%
# calculate the ratio of helpfulness for each review using the first number divided by the second number in the 'review/helpful' column split by the '/' character
books_ratings['helpfulness_ratio'] = books_ratings['review/helpfulness'].str.split('/').apply(lambda x: int(x[0]) / int(x[1]) if int(x[1]) != 0 else 0)

# %%
# set pandas options to display all columns
pd.set_option('display.max_columns', None)

# %%
# top 5
books_ratings.head()
# Out:
#                             Title  \
# 0  Its Only Art If Its Well Hung!
# 1        Dr. Seuss: American Icon
# 2        Dr. Seuss: American Icon
# 3        Dr. Seuss: American Icon
# 4        Dr. Seuss: American Icon
#
#                                          description       authors  \
# 0                                                NaN  Julie Strain
# 1  Philip Nel takes a fascinating look into the k...    Philip Nel
# 2  Philip Nel takes a fascinating look into the k...    Philip Nel
# 3  Philip Nel takes a fascinating look into the k...    Philip Nel
# 4  Philip Nel takes a fascinating look into the k...    Philip Nel
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=IjvHQ...
# 3  http://books.google.com/books/content?id=IjvHQ...
# 4  http://books.google.com/books/content?id=IjvHQ...
#
#                                          previewLink  publisher publishedDate  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN          1996
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 3  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 4  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 3  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 4  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
#
#                   categories  ratingsCount          Id  Price         User_id  \
# 0    Comics & Graphic Novels           NaN  1882931173    NaN   AVCGYZL8FQQTD
# 1  Biography & Autobiography           NaN  0826414346    NaN  A30TK6U7DNS82R
# 2  Biography & Autobiography           NaN  0826414346    NaN  A3UH4UZ4RSVO82
# 3  Biography & Autobiography           NaN  0826414346    NaN  A2MVUWT453QH61
# 4  Biography & Autobiography           NaN  0826414346    NaN  A22X4XUPKF66MR
#
#                           profileName review/helpfulness  review/score  \
# 0               Jim of Oz "jim-of-oz"                7/7           4.0
# 1                       Kevin Killian              10/10           5.0
# 2                        John Granger              10/11           5.0
# 3  Roy E. Perry "amateur philosopher"                7/7           4.0
# 4     D. H. Richards "ninthwavestore"                3/3           4.0
#
#   review/time                                   review/summary  \
# 0  1999-10-23           Nice collection of Julie Strain images
# 1  2004-09-21                                Really Enjoyed It
# 2  2004-03-09  Essential for every personal and Public Library
# 3  2004-07-25  Phlip Nel gives silly Seuss a serious treatment
# 4  2005-02-10                           Good academic overview
#
#                                          review/text published_year  \
# 0  This is only for Julie Strain fans. It's a col...           1996
# 1  I don't care much for Dr. Seuss but after read...           2005
# 2  If people become the books they read and if "t...           2005
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...           2005
# 4  Philip Nel - Dr. Seuss: American IconThis is b...           2005
#
#    review_id  helpfulness_ratio
# 0          1           1.000000
# 1          2           1.000000
# 2          3           0.909091
# 3          4           1.000000
# 4          5           1.000000

# %%
# top 5 of books 
# books.head()

# %% [markdown]
# ### Book dataset

# %%
# columns
# books.columns

# %%
# decompose the data into two tables: books and reviews
books_new = books_ratings[['Id', 'Title', 'description', 'authors', 'image', 'previewLink', 'publisher',
       'publishedDate', 'published_year', 'infoLink', 'categories', 'ratingsCount']].drop_duplicates()

# %%
# top 5
# books_new.head()

# %%
# shape
books_new.shape
# Out:
# (221998, 12)

# %%
# Id unique count
books_new['Id'].nunique()
# Out:
# 221998

# %% [markdown]
# The Id column is unique for each row. Can be used as primary key.

# %%
# top 5
# books_new.head()

# %%
# replace column names with the new names
books_new.columns = ['book_id', 'title', 'description', 'authors', 'image', 'preview_link', 'publisher',
       'published_date', 'published_year', 'info_link', 'categories', 'ratings_count']

# %%
# top 5
books_new.head()
# Out:
#        book_id                                              title  \
# 0   1882931173                     Its Only Art If Its Well Hung!
# 1   0826414346                           Dr. Seuss: American Icon
# 10  0829814000              Wonderful Worship in Smaller Churches
# 14  0595344550                      Whispers of the Wicked Saints
# 46  0253338352  Nation Dance: Religion, Identity and Cultural ...
#
#                                           description          authors  \
# 0                                                 NaN     Julie Strain
# 1   Philip Nel takes a fascinating look into the k...       Philip Nel
# 10  This resource includes twelve principles in un...     David R. Ray
# 14  Julia Thomas finds her life spinning out of co...  Veronica Haddon
# 46                                                NaN      Edward Long
#
#                                                 image  \
# 0   http://books.google.com/books/content?id=DykPA...
# 1   http://books.google.com/books/content?id=IjvHQ...
# 10  http://books.google.com/books/content?id=2tsDA...
# 14  http://books.google.com/books/content?id=aRSIg...
# 46                                                NaN
#
#                                          preview_link  publisher  \
# 0   http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN
# 1   http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black
# 10  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN
# 14  http://books.google.nl/books?id=aRSIgJlq6JwC&d...  iUniverse
# 46  http://books.google.nl/books?id=399SPgAACAAJ&d...        NaN
#
#    published_date published_year  \
# 0            1996           1996
# 1      2005-01-01           2005
# 10           2000           2000
# 14        2005-02           2005
# 46     2003-03-01           2003
#
#                                             info_link  \
# 0   http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1   http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 10  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 14  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 46  http://books.google.nl/books?id=399SPgAACAAJ&d...
#
#                    categories  ratings_count
# 0     Comics & Graphic Novels            NaN
# 1   Biography & Autobiography            NaN
# 10                   Religion            NaN
# 14                    Fiction            NaN
# 46                        NaN            NaN

# %% [markdown]
# ### Review dataset

# %%
# top 5
# ratings.head()

# %%
# ratings columns
# ratings.columns

# %%
# top 5
# books_ratings.head()

# %%
# create a new table for the ratings data
ratings_new = books_ratings[['review_id', 'Id', 'Title', 'Price', 'User_id', 'profileName', 'helpfulness_ratio',
       'review/score', 'review/time', 'review/summary', 'review/text']].drop_duplicates()

# %%
# replace column names with the new names
ratings_new.columns = ['review_id', 'book_id', 'title', 'price', 'user_id', 'profile_name', 'helpfulness_ratio',
       'review_score', 'review_time', 'review_summary', 'review_text']

# %%
# top 5
ratings_new.head()
# Out:
#    review_id     book_id                           title  price  \
# 0          1  1882931173  Its Only Art If Its Well Hung!    NaN
# 1          2  0826414346        Dr. Seuss: American Icon    NaN
# 2          3  0826414346        Dr. Seuss: American Icon    NaN
# 3          4  0826414346        Dr. Seuss: American Icon    NaN
# 4          5  0826414346        Dr. Seuss: American Icon    NaN
#
#           user_id                        profile_name  helpfulness_ratio  \
# 0   AVCGYZL8FQQTD               Jim of Oz "jim-of-oz"           1.000000
# 1  A30TK6U7DNS82R                       Kevin Killian           1.000000
# 2  A3UH4UZ4RSVO82                        John Granger           0.909091
# 3  A2MVUWT453QH61  Roy E. Perry "amateur philosopher"           1.000000
# 4  A22X4XUPKF66MR     D. H. Richards "ninthwavestore"           1.000000
#
#    review_score review_time                                   review_summary  \
# 0           4.0  1999-10-23           Nice collection of Julie Strain images
# 1           5.0  2004-09-21                                Really Enjoyed It
# 2           5.0  2004-03-09  Essential for every personal and Public Library
# 3           4.0  2004-07-25  Phlip Nel gives silly Seuss a serious treatment
# 4           4.0  2005-02-10                           Good academic overview
#
#                                          review_text
# 0  This is only for Julie Strain fans. It's a col...
# 1  I don't care much for Dr. Seuss but after read...
# 2  If people become the books they read and if "t...
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...
# 4  Philip Nel - Dr. Seuss: American IconThis is b...

# %%
# ratings shape
ratings_new.shape
# Out:
# (3000000, 11)

# %%
# review id unique count
ratings_new['review_id'].nunique()
# Out:
# 3000000

# %% [markdown]
# review_id is unique identifier for each row. Can be used as primary key.

# %%
# save the books and ratings data to csv files
books_new.to_csv('books_new.csv', index=False)
ratings_new.to_csv('ratings_new.csv', index=False)

# %%
# test
# read the books data
books_new = pd.read_csv('books_new.csv')

# %%
# top 5
books_new.head()
# Out:
#       book_id                                              title  \
# 0  1882931173                     Its Only Art If Its Well Hung!
# 1  0826414346                           Dr. Seuss: American Icon
# 2  0829814000              Wonderful Worship in Smaller Churches
# 3  0595344550                      Whispers of the Wicked Saints
# 4  0253338352  Nation Dance: Religion, Identity and Cultural ...
#
#                                          description          authors  \
# 0                                                NaN     Julie Strain
# 1  Philip Nel takes a fascinating look into the k...       Philip Nel
# 2  This resource includes twelve principles in un...     David R. Ray
# 3  Julia Thomas finds her life spinning out of co...  Veronica Haddon
# 4                                                NaN      Edward Long
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
# 3  http://books.google.com/books/content?id=aRSIg...
# 4                                                NaN
#
#                                         preview_link  publisher  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...  iUniverse
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...        NaN
#
#   published_date  published_year  \
# 0           1996          1996.0
# 1     2005-01-01          2005.0
# 2           2000          2000.0
# 3        2005-02          2005.0
# 4     2003-03-01          2003.0
#
#                                            info_link  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...
#
#                   categories  ratings_count
# 0    Comics & Graphic Novels            NaN
# 1  Biography & Autobiography            NaN
# 2                   Religion            NaN
# 3                    Fiction            NaN
# 4                        NaN            NaN

# %%
# read the ratings data
ratings_new = pd.read_csv('ratings_new.csv')

# %%
# top 5
ratings_new.head()
# Out:
#    review_id     book_id                           title  price  \
# 0          1  1882931173  Its Only Art If Its Well Hung!    NaN
# 1          2  0826414346        Dr. Seuss: American Icon    NaN
# 2          3  0826414346        Dr. Seuss: American Icon    NaN
# 3          4  0826414346        Dr. Seuss: American Icon    NaN
# 4          5  0826414346        Dr. Seuss: American Icon    NaN
#
#           user_id                        profile_name  helpfulness_ratio  \
# 0   AVCGYZL8FQQTD               Jim of Oz "jim-of-oz"           1.000000
# 1  A30TK6U7DNS82R                       Kevin Killian           1.000000
# 2  A3UH4UZ4RSVO82                        John Granger           0.909091
# 3  A2MVUWT453QH61  Roy E. Perry "amateur philosopher"           1.000000
# 4  A22X4XUPKF66MR     D. H. Richards "ninthwavestore"           1.000000
#
#    review_score review_time                                   review_summary  \
# 0           4.0  1999-10-23           Nice collection of Julie Strain images
# 1           5.0  2004-09-21                                Really Enjoyed It
# 2           5.0  2004-03-09  Essential for every personal and Public Library
# 3           4.0  2004-07-25  Phlip Nel gives silly Seuss a serious treatment
# 4           4.0  2005-02-10                           Good academic overview
#
#                                          review_text
# 0  This is only for Julie Strain fans. It's a col...
# 1  I don't care much for Dr. Seuss but after read...
# 2  If people become the books they read and if "t...
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...
# 4  Philip Nel - Dr. Seuss: American IconThis is b...
